# %%
import numpy as np

# %%
x = np.array ([[25],[2],[-3],[-23]])
print (x)
# Out:
# [[ 25]
#  [  2]
#  [ -3]
#  [-23]]

# %%
x_t = x.T
print (x_t)
# Out:
# [[ 25   2  -3 -23]]

# %%
import torch
import tensorflow as tf

# %%
v = torch.tensor ([[25],[2],[-3],[-23]])
print (v)
# Out:
# tensor([[ 25],
#         [  2],
#         [ -3],
#         [-23]])

# %%
v_t = v.T
print (v)
# Out:
# tensor([[ 25],
#         [  2],
#         [ -3],
#         [-23]])

# %%
z = tf.Variable ([[25],[2],[-3],[-23]])
print (z)
# Out:
# <tf.Variable 'Variable:0' shape=(4, 1) dtype=int32, numpy=
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]], dtype=int32)>

# %%
z_t = tf.transpose(z)
print (z_t)
# Out:
# tf.Tensor([[ 25   2  -3 -23]], shape=(1, 4), dtype=int32)
