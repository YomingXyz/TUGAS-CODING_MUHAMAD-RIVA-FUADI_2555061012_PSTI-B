# %% [markdown]
# Vectors (Rank 1 Tensors) in NumPy

# %%
import numpy as np

# %%
x = np.array([12, 12, 12])
x
# Out:
# array([12, 12, 12])

# %%
len(x)
# Out:
# 3

# %%
x.shape
# Out:
# (3,)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x[0]
# Out:
# np.int64(12)

# %%
type(x[0])
# Out:
# numpy.int64

# %% [markdown]
# Vector Transposition

# %%
#lakukan transpose pada vector x dan simpan pada variabel x_tx_t = x.T
x_t
# Out:
# array([12, 12, 12])

# %%
#tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_ty
y = np.array([[12, 12, 12]])
print(y.shape)
y_t = y.T
y_t
# Out:
# (1, 3)
# array([[12],
#        [12],
#        [12]])

# %%
#tampilkan ukuran dari vector y_t
y_t.shape
# Out:
# (3, 1)

# %% [markdown]
# Vectors in PyTorch and TensorFlow

# %%
import torch
import tensorflow as tf

# %%
#lakukan transpose pada vector x dan simpan pada variabel x_pt
x_pt = torch.tensor([12, 12, 12])
x_pt
# Out:
# tensor([12, 12, 12])

# %%
#tampilkan ukuran dari vector x_pt
x_pt.shape
# Out:
# torch.Size([3])

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_pt
y_pt = np.array([[12, 12, 12]])
print(y_pt.shape)
y_pt = y_pt.T
y_pt
# Out:
# (1, 3)
# array([[12],
#        [12],
#        [12]])

# %%
#tampilkan ukuran dari vector y_pt
y_pt.shape
# Out:
# (3, 1)

# %%
#lakukan transpose pada vector x dan simpan pada variabel x_tf
x_tf = torch.tensor([12, 12, 12])
x_tf
# Out:
# tensor([12, 12, 12])

# %%
#tampilkan ukuran dari vector x_tf
x_tf.shape
# Out:
# torch.Size([3])

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_tf
y_tf = np.array([[12, 12, 12]])
print(y_tf.shape)
y_tf = y_tf.T
y_tf
# Out:
# (1, 3)
# array([[12],
#        [12],
#        [12]])

# %%
#tampilkan ukuran dari vector y_tf
y_tf.shape
# Out:
# (3, 1)
