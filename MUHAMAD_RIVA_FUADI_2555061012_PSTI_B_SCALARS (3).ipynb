# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x = 12

# %%
#tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y = 12
y
# Out:
# 12

# %%
#tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
#jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 24

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 12.0
x_float
# Out:
# 12.0

# %%
#jumlahkan x_float dengan y
x_float = 12.0
float_sum = x_float + y
float_sum
# Out:
# 24.0

# %%
#tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %% [markdown]
# lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x_tf = tf.Variable(12, dtype=tf.int16)
#tampilkan tipe data dari x
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=12>

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y_tf = tf.Variable(12, dtype=tf.int16)
#tampilkan tipe data dari y
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=12>

# %%
#jumlahkan x+y
tf_sum = tf.add(x_tf, y_tf)
print(tf_sum)
# Out:
# tf.Tensor(24, shape=(), dtype=int16)

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_tf = tf.Variable(12.0, dtype=tf.float16)
#tampilkan tipe data dari x_float
x_float_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=12.0>

# %%
#jumlahkan x_float dengan y
tf_float_sum = tf.add(tf.cast(y_tf, dtype = tf.float16), x_float_tf)
print(tf_float_sum)
# Out:
# tf.Tensor(24.0, shape=(), dtype=float16)

# %%
import torch

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x_pt = torch.tensor(12)
x_pt
# Out:
# tensor(12)

# %%
#tampilkan tipe data dari x
x_pt.dtype
# Out:
# torch.int64

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y_pt = torch.tensor(12)
y_pt
# Out:
# tensor(12)

# %%
#tampilkan tipe data dari y
y_pt.dtype
# Out:
# torch.int64

# %%
#jumlahkan x+y
x_pt + y_pt
# Out:
# tensor(24)

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_pt = torch.tensor(12.0)
#tampilkan tipe data dari x_float
x_float_pt
# Out:
# tensor(12.)

# %%
#jumlahkan x_float dengan y
x_float_pt + y_pt
# Out:
# tensor(24.)

# %%
#tampilkan tipe data dari y_float
x_float_pt.dtype
# Out:
# torch.float32
